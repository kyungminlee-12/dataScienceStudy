# %% [markdown]
# # 직선과 점의 거리
# ### data science school pg 163

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $\Vert x'^{\Vert w}\Vert$ - $\Vert w \Vert$
# ~~~
# :점 x'와 (백터 w를 지나고 벡터 w에 수직인 직선) 사이의 거리
# ~~~
# $\Vert x'^{\Vert w}\Vert$ = (w.T @ x')/ $\Vert w \Vert$
#
# ~~~
# 직선의 방정식 w.Tx-w_0=0 과 점 사이의 거리는
# ~~~
# : |w.T@x'-w_0| / $\Vert w \Vert$

# %%
w=np.array([1, 2])
x1=np.array([4, 3])
x2=np.array([1, 2])*2

gray={'facecolor': 'gray'}         #facecolor라는 것을 gray로 설정하는 명령어
black={'facecolor': 'black'}
red={'facecolor': 'red'}
green={'facecolor': 'green'}
blue={'facecolor': 'blue'}

plt.annotate('', xy=x1, xytext=(0, 0), arrowprops=gray)
plt.annotate('', xy=x2, xytext=(0, 0), arrowprops=gray)
plt.annotate('', xy=w, xytext=(0, 0), arrowprops=red)

plt.plot(0, 0, 'kP', ms=10)
plt.plot(w[0], w[1], 'ro', ms=10)
plt.plot(x1[0], x1[1], 'ro', ms=10)
plt.plot([-3, 7], [4, -1], 'r-', lw=5)
plt.plot([2, 4], [4, 3], 'k:', lw=2)
plt.plot([3, 4], [1, 3], 'k:', lw=2)

plt.text(0.1, 0.9, '$w$')
plt.text(4.2, 3.1, '$x\'$')
plt.text(1.5, 2.4, '$x\'^{\Vert w}$')

plt.xticks(np.arange(-3, 15))
plt.yticks(np.arange(-1, 5))

plt.xlim(-3, 7)
plt.ylim(-1, 5)
plt.show()
